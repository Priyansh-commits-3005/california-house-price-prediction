# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("housing.csv")
dataset
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
dataset.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
dataset.dropna(inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x = dataset[['longitude', 'latitude', 'housing_median_age',
             'total_rooms','total_bedrooms', 'population', 
             'households', 'median_income','ocean_proximity']]

y = dataset['median_house_value']

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data = X_train.join(y_train)
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7190     -118.17     34.05                45.0        733.0           178.0
# 12005    -117.55     33.89                25.0       2999.0           439.0
# 8471     -118.32     33.91                33.0       1729.0           396.0
# 3288     -122.73     39.04                23.0       1618.0           395.0
# 12305    -116.71     33.75                25.0      10665.0          2161.0
#
#        population  households  median_income ocean_proximity  \
# 7190        715.0       165.0         2.5962       <1H OCEAN
# 12005      1396.0       458.0         5.6973          INLAND
# 8471       1073.0       344.0         4.2083       <1H OCEAN
# 3288        425.0       244.0         1.9833          INLAND
# 12305      1874.0       852.0         3.0625          INLAND
#
#        median_house_value
# 7190             124100.0
# 12005            164800.0
# 8471             180500.0
# 3288             111500.0
# 12305            150500.0

# %% [markdown]
# evaluation

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18956\1402113604.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train_data.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.923460           -0.113750     0.049639
# latitude            -0.923460  1.000000            0.016101    -0.041864
# housing_median_age  -0.113750  0.016101            1.000000    -0.359981
# total_rooms          0.049639 -0.041864           -0.359981     1.000000
# total_bedrooms       0.073144 -0.071797           -0.319751     0.930943
# population           0.102185 -0.111852           -0.290942     0.856128
# households           0.060201 -0.076903           -0.301451     0.919142
# median_income       -0.010101 -0.085593           -0.117006     0.199417
# median_house_value  -0.041094 -0.150567            0.107434     0.135180
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.073144    0.102185    0.060201      -0.010101
# latitude                 -0.071797   -0.111852   -0.076903      -0.085593
# housing_median_age       -0.319751   -0.290942   -0.301451      -0.117006
# total_rooms               0.930943    0.856128    0.919142       0.199417
# total_bedrooms            1.000000    0.876068    0.979011      -0.006220
# population                0.876068    1.000000    0.906597       0.007594
# households                0.979011    0.906597    1.000000       0.015564
# median_income            -0.006220    0.007594    0.015564       1.000000
# median_house_value        0.054519   -0.021992    0.068771       0.685430
#
#                     median_house_value
# longitude                    -0.041094
# latitude                     -0.150567
# housing_median_age            0.107434
# total_rooms                   0.135180
# total_bedrooms                0.054519
# population                   -0.021992
# households                    0.068771
# median_income                 0.685430
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18956\1685986096.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# <Axes: >

# %%
#fixing skewed data 
#total_rooms,total_bedrooms,population,households
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households']+1)

# %%
train_data.hist()
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# fixing ocean proximity

# %%
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7190     -118.17     34.05                45.0     6.598509        5.187386
# 12005    -117.55     33.89                25.0     8.006368        6.086775
# 8471     -118.32     33.91                33.0     7.455877        5.983936
# 3288     -122.73     39.04                23.0     7.389564        5.981414
# 12305    -116.71     33.75                25.0     9.274816        7.678789
# ...          ...       ...                 ...          ...             ...
# 13970    -116.85     34.26                19.0     8.593413        7.107425
# 6966     -118.06     33.99                45.0     7.294377        5.545177
# 6917     -118.01     33.95                35.0     7.470794        5.777652
# 12223    -116.89     33.73                15.0     7.647309        5.758902
# 15188    -117.05     33.03                14.0     8.552753        6.958448
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 7190     6.573680    5.111988         2.5962            124100.0          1
# 12005    7.242082    6.129050         5.6973            164800.0          0
# 8471     6.979145    5.843544         4.2083            180500.0          1
# 3288     6.054439    5.501258         1.9833            111500.0          0
# 12305    7.536364    6.748760         3.0625            150500.0          0
# ...           ...         ...            ...                 ...        ...
# 13970    6.889591    5.905362         2.6094             92400.0          0
# 6966     6.508769    5.525453         4.5478            188000.0          1
# 6917     6.652863    5.673323         5.0861            296700.0          1
# 12223    6.843750    5.627621         5.3623            201300.0          0
# 15188    7.402452    6.899723         4.5000            222200.0          1
#
#        INLAND  NEAR BAY  NEAR OCEAN
# 7190        0         0           0
# 12005       1         0           0
# 8471        0         0           0
# 3288        1         0           0
# 12305       1         0           0
# ...       ...       ...         ...
# 13970       1         0           0
# 6966        0         0           0
# 6917        0         0           0
# 12223       1         0           0
# 15188       0         0           0
#
# [16346 rows x 13 columns]

# %% [markdown]
# Feature Engineering

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_ratio'] = train_data['total_rooms']/train_data['households']

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7190     -118.17     34.05                45.0     6.598509        5.187386
# 12005    -117.55     33.89                25.0     8.006368        6.086775
# 8471     -118.32     33.91                33.0     7.455877        5.983936
# 3288     -122.73     39.04                23.0     7.389564        5.981414
# 12305    -116.71     33.75                25.0     9.274816        7.678789
# ...          ...       ...                 ...          ...             ...
# 13970    -116.85     34.26                19.0     8.593413        7.107425
# 6966     -118.06     33.99                45.0     7.294377        5.545177
# 6917     -118.01     33.95                35.0     7.470794        5.777652
# 12223    -116.89     33.73                15.0     7.647309        5.758902
# 15188    -117.05     33.03                14.0     8.552753        6.958448
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 7190     6.573680    5.111988         2.5962            124100.0          1
# 12005    7.242082    6.129050         5.6973            164800.0          0
# 8471     6.979145    5.843544         4.2083            180500.0          1
# 3288     6.054439    5.501258         1.9833            111500.0          0
# 12305    7.536364    6.748760         3.0625            150500.0          0
# ...           ...         ...            ...                 ...        ...
# 13970    6.889591    5.905362         2.6094             92400.0          0
# 6966     6.508769    5.525453         4.5478            188000.0          1
# 6917     6.652863    5.673323         5.0861            296700.0          1
# 12223    6.843750    5.627621         5.3623            201300.0          0
# 15188    7.402452    6.899723         4.5000            222200.0          1
#
#        INLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_ratio
# 7190        0         0           0       0.786145         1.290791
# 12005       1         0           0       0.760242         1.306298
# 8471        0         0           0       0.802580         1.275917
# 3288        1         0           0       0.809441         1.343250
# 12305       1         0           0       0.827918         1.374299
# ...       ...       ...         ...            ...              ...
# 13970       1         0           0       0.827078         1.455188
# 6966        0         0           0       0.760199         1.320141
# 6917        0         0           0       0.773365         1.316829
# 12223       1         0           0       0.753063         1.358888
# 15188       0         0           0       0.813592         1.239579
#
# [16346 rows x 15 columns]

# %%
#heatmap with the new features marking the end of data preprocessing
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
X_train,y_train = train_data.drop(['median_house_value'],axis = 1) , train_data['median_house_value']

# %%
test_data = X_test.join(y_test)

# %%
test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households']+1)

# %%
test_data = test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
test_data['bedroom_ratio'] = test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_ratio'] = test_data['total_rooms']/test_data['households']

# %%
X_test ,y_test = test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7190     -118.17     34.05                45.0     6.598509        5.187386
# 12005    -117.55     33.89                25.0     8.006368        6.086775
# 8471     -118.32     33.91                33.0     7.455877        5.983936
# 3288     -122.73     39.04                23.0     7.389564        5.981414
# 12305    -116.71     33.75                25.0     9.274816        7.678789
# ...          ...       ...                 ...          ...             ...
# 13970    -116.85     34.26                19.0     8.593413        7.107425
# 6966     -118.06     33.99                45.0     7.294377        5.545177
# 6917     -118.01     33.95                35.0     7.470794        5.777652
# 12223    -116.89     33.73                15.0     7.647309        5.758902
# 15188    -117.05     33.03                14.0     8.552753        6.958448
#
#        population  households  median_income  <1H OCEAN  INLAND  NEAR BAY  \
# 7190     6.573680    5.111988         2.5962          1       0         0
# 12005    7.242082    6.129050         5.6973          0       1         0
# 8471     6.979145    5.843544         4.2083          1       0         0
# 3288     6.054439    5.501258         1.9833          0       1         0
# 12305    7.536364    6.748760         3.0625          0       1         0
# ...           ...         ...            ...        ...     ...       ...
# 13970    6.889591    5.905362         2.6094          0       1         0
# 6966     6.508769    5.525453         4.5478          1       0         0
# 6917     6.652863    5.673323         5.0861          1       0         0
# 12223    6.843750    5.627621         5.3623          0       1         0
# 15188    7.402452    6.899723         4.5000          1       0         0
#
#        NEAR OCEAN  bedroom_ratio  household_ratio
# 7190            0       0.786145         1.290791
# 12005           0       0.760242         1.306298
# 8471            0       0.802580         1.275917
# 3288            0       0.809441         1.343250
# 12305           0       0.827918         1.374299
# ...           ...            ...              ...
# 13970           0       0.827078         1.455188
# 6966            0       0.760199         1.320141
# 6917            0       0.773365         1.316829
# 12223           0       0.753063         1.358888
# 15188           0       0.813592         1.239579
#
# [16346 rows x 14 columns]

# %% [markdown]
# Random Forest Resgressor model

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test,y_test)
# Out:
# 0.8165004331292628

# %% [markdown]
# cross validation

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()
param_grid = {
    'n_estimators':[271,272,273],
    'min_samples_split':[2,4],
    'max_depth':[None,4,8]
}

grid_search = GridSearchCV(forest,param_grid= param_grid,cv=5,scoring='neg_mean_squared_error',return_train_score=True)
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [271, 272, 273]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(n_estimators=272)

# %%
grid_search.best_estimator_.score(X_test,y_test)
# Out:
# 0.8182542199164579
